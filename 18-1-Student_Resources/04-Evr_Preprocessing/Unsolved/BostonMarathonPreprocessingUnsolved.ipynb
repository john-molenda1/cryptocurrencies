# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %matplotlib inline

# %%
df = pd.read_csv('../Resources/marathon_results_2019.csv')
df.head()
# Out:
#   Bib               Name  Age M/F      City State Country Citizen Unnamed: 8  \
# 0   2  Cherono, Lawrence   30   M   Eldoret   NaN     KEN     NaN        NaN
# 1   6     Desisa, Lelisa   29   M      Ambo   NaN     ETH     NaN        NaN
# 2   7  Kipkemoi, Kenneth   34   M   Eldoret   NaN     KEN     NaN        NaN
# 3   8      Kandie, Felix   32   M      Iten   NaN     KEN     NaN        NaN
# 4  11    Kirui, Geoffrey   26   M  Keringet   NaN     KEN     NaN        NaN
#
#         5K  ...      25K      30K      35K      40K     Pace Proj Time  \
# 0  0:15:11  ...  1:16:23  1:32:01  1:47:16  2:01:45  0:04:53       NaN
# 1  0:15:10  ...  1:16:24  1:32:01  1:47:16  2:01:46  0:04:53       NaN
# 2  0:15:14  ...  1:16:24  1:32:01  1:47:16  2:01:45  0:04:54       NaN
# 3  0:15:14  ...  1:16:24  1:32:01  1:47:16  2:02:08  0:04:55       NaN
# 4  0:15:12  ...  1:16:23  1:32:01  1:47:16  2:01:57  0:04:56       NaN
#
#   Official Time Overall Gender Division
# 0       2:07:57       1      1        1
# 1       2:07:59       2      2        2
# 2       2:08:07       3      3        3
# 3       2:08:54       4      4        4
# 4       2:08:55       5      5        5
#
# [5 rows x 24 columns]

# %%
# Subset the dataframe to only the columns "Age", "M/F", split times (i.e. "5K, 10K", etc.), "Pace", and "Official Time". 
### YOUR CODE HERE ##
X = df[['Age', 'M/F', '5K', '10K', '15K', '20K', 'Half','25K', '30K', '35K', '40K', 'Pace', 'Official Time']]
X.head()
# Out:
#    Age M/F       5K      10K      15K      20K     Half      25K      30K  \
# 0   30   M  0:15:11  0:30:21  0:45:48  1:01:16  1:04:29  1:16:23  1:32:01
# 1   29   M  0:15:10  0:30:22  0:45:46  1:01:16  1:04:30  1:16:24  1:32:01
# 2   34   M  0:15:14  0:30:22  0:45:47  1:01:17  1:04:31  1:16:24  1:32:01
# 3   32   M  0:15:14  0:30:24  0:45:47  1:01:16  1:04:31  1:16:24  1:32:01
# 4   26   M  0:15:12  0:30:21  0:45:46  1:01:15  1:04:28  1:16:23  1:32:01
#
#        35K      40K     Pace Official Time
# 0  1:47:16  2:01:45  0:04:53       2:07:57
# 1  1:47:16  2:01:46  0:04:53       2:07:59
# 2  1:47:16  2:01:45  0:04:54       2:08:07
# 3  1:47:16  2:02:08  0:04:55       2:08:54
# 4  1:47:16  2:01:57  0:04:56       2:08:55

# %%
# Convert the split times, "Pace", and "Official Time" to timedeltas using apply() and pandas.to_timedelta()
### YOUR CODE HERE ###
time_columns = ['5K', '10K', '15K', '20K', 'Half','25K', '30K', '35K', '40K', 'Pace', 'Official Time']
df[time_columns] = df[time_columns].apply(pd.to_timedelta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: symbols w/o a number
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\JOHN~1.MOL\AppData\Local\Temp/ipykernel_5756/887027738.py in <module>
#       2 ### YOUR CODE HERE ###
#       3 time_columns = ['5K', '10K', '15K', '20K', 'Half','25K', '30K', '35K', '40K', 'Pace', 'Official Time']
# ----> 4 df[time_columns] = df[time_columns].apply(pd.to_timedelta)
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\tools\timedeltas.py in to_timedelta(arg, unit, errors)
#     122         return arg
#     123     elif isinstance(arg, ABCSeries):
# --> 124         values = _convert_listlike(arg._values, unit=unit, errors=errors)
#     125         return arg._constructor(values, index=arg.index, name=arg.name)
#     126     elif isinstance(arg, ABCIndex):
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\tools\timedeltas.py in _convert_listlike(arg, unit, errors, name)
#     171
#     172     try:
# --> 173         td64arr = sequence_to_td64ns(arg, unit=unit, errors=errors, copy=False)[0]
#     174     except ValueError:
#     175         if errors == "ignore":
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\arrays\timedeltas.py in sequence_to_td64ns(data, copy, unit, errors)
#     989     if is_object_dtype(data.dtype) or is_string_dtype(data.dtype):
#     990         # no need to make a copy, need to convert if string-dtyped
# --> 991         data = objects_to_td64ns(data, unit=unit, errors=errors)
#     992         copy = False
#     993
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\core\arrays\timedeltas.py in objects_to_td64ns(data, unit, errors)
#    1098     values = np.array(data, dtype=np.object_, copy=False)
#    1099
# -> 1100     result = array_to_timedelta64(values, unit=unit, errors=errors)
#    1101     return result.view("timedelta64[ns]")
#    1102
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.array_to_timedelta64()
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.convert_to_timedelta64()
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.parse_timedelta_string()
#
# ValueError: symbols w/o a number

# %%
# Convert timedeltas to seconds by applying the lambda function lambda x: x.dt.total_seconds()
### YOUR CODE HERE ###
df[['Pace', 'Official Time']].apply(lambda x: x.dt.total_seconds())
df[['Pace', 'Official Time']].head()

# %%
# Subset df to only rows where the split values are non-zero
### YOUR CODE HERE ###

# %%
# Use LabelEncoder to convert 'M/F' into integer labels
### YOUR CODE HERE ###

# %%
# Convert 'Age' to a numeric value
### YOUR CODE HERE ###

# %%
# 'Pace' should be perfectly correlated with 'Official Time', so we'll remove it from our X data (but keep it for analysis)
# Plot a scatter plot of 'Pace' against 'Official Time' to make sure
### YOUR CODE HERE ###

# %%
# Create a training set 'X' with every column except 'Pace'
### YOUR CODE HERE ###

# %%
# Scale the dataset using MinMaxScaler()
### YOUR CODE HERE ###
